# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import optimize
from scipy import integrate
from scipy import interpolate

# %%
#Incluye la carpeta con el carchivo
path="/Users/namh2/OneDrive/Documentos/DOCTORADO/AJUSTES Y ERRORES LANE-EMDEN/Blok_McGaugh_Rubin_2001/"
data=np.loadtxt(path+"ESO3020120.dat")

# %%
RCr_data = np.array([row[1] for row in data])# galactocentric distance [kpc]
RCv_data = np.array([row[5] for row in data])# rotation velocity [km/s]
RCev_data = np.array([row[6] for row in data])# error in rotation velocity [km/s]

# %%
plt.errorbar(RCr_data,RCv_data,yerr=RCev_data,fmt='.')
plt.ylabel(r'$v_{c}(r)$[km/s]')
plt.xlabel("r[kpc]")
# Out:
# Text(0.5, 0, 'r[kpc]')

# %%
def Integrate(func,x0,y0,x,h):
    def RK4(func,x0,y0,h):
        K0 = h*func(x0,y0)
        K1 = h*func(x0 + 0.5*h, y0 + 0.5*K0)
        K2 = h*func(x0 + 0.5*h, y0 + 0.5*K1)
        K3 = h*func(x0 + h, y0 + K2)
        return (K0 + 2.*K1 + 2.*K2 + K3)/6.
    X = []
    Y = []
    X.append(x0)
    Y.append(y0)
    while y0[0] < 4.90000000000:
        y0 = y0 + RK4(func,x0,y0,h) 
        x0 = x0 + h 
        X.append(x0)
        Y.append(y0)
    return np.array(X),np.array(Y)

# %%
#Ecuaciones a resolver y[1]-->P, K
def rhs(x,y):
    dy=np.zeros(2)
    dy[0]=4*np.pi*Gm*x**2*(y[1]/K)
    dy[1]=-Gp*y[0]/x**2*(y[1]/K)
    return dy

# %%
def model(data,v,X):
    V = []
    x=X
    RC=v*np.sqrt(G)
    Int_l = interpolate.interp1d(x,RC)   #,fill_value='extrapolate')
    for i in range(len(data)):
        if data[i] < x[-1]:
            v=Int_l(data[i])
            V.append(v)
        else:
            #v=0.
            v=np.sqrt(G*Y[:,0][-1]/(data[i]))
            V.append(v)
    return V,RC

# %%
def Xi2(RCv_data,RCv_teo,RCev_data):
    xi=np.sum((RCv_data-RCv_teo)**2./(RCev_data)**2.)
    return xi

# %%
Gm=2.5188027*10**(-3)
Gp=0.499246*10**(-6)
G=4.258*10**(4)
Gv=1.24*10**(5)
y0=np.zeros(2)
h=0.001
x0=0.00001

# %%
#K_min=2*10**(-7)
#K_max=0.5*10**(-6)
K_min=0.9*10**(-8)
K_max=5.*10**(-8)
Kvec=np.linspace(K_min,K_max,100)
#p_0min=5.*10**(-12)
#p_0max=7.*10**(-6)
p_0min=4.9*10**(-8)
p_0max=9.1*10**(-8)
p_0=np.linspace(p_0min,p_0max,100)

# %%
y0[0]=0.
y0[1]=p_0[0]
K=K_min

# %%
X,Y=Integrate(rhs,x0,y0,10.,h)
v=np.sqrt(Y[:,0]/X)
plt.plot(X,v)

# %%
V,RC=model(RCr_data,v,X)
plt.errorbar(RCr_data,RCv_data,yerr=RCev_data,fmt='.')
plt.plot(RCr_data,V)
plt.ylabel(r'$V$[km/s]')
plt.xlabel("R[kpc]")
# Out:
# Text(0.5, 0, 'R[kpc]')

# %%
# %%time
xi_minimo=10000
xi = np.zeros((len(p_0),len(Kvec)))
for l in range(0,len(Kvec)):
    K=Kvec[l]
    for i in range(0,len(p_0)):
        x0=0.00001
        y0[0]=0.
        y0[1]=p_0[i]
        X,Y=Integrate(rhs,x0,y0,10.,h)
        v=np.sqrt(Y[:,0]/X)
        V,RC=model(RCr_data,v,X)
        xi[i,l]=Xi2(RCv_data,V,RCev_data)
        if (xi[i,l] < xi_minimo):
            xi_minimo=xi[i,l]
            p0_minimo=p_0[i]
            K_minimo=Kvec[l]
# Out:
# Wall time: 4h 17min 27s

# %%
rho0_minimo=p0_minimo/K_minimo
print(xi_minimo)
print(K_minimo)
print(p0_minimo)
print(rho0_minimo)
print(V)
print(RC)
print(X)
plt.plot(X,RC)
# Out:
# 0.01476174250768186
# 3.426262626262626e-08
# 5.96060606060606e-08
# 1.739681603773585
# [array(5.71229724), array(19.73941972), array(37.93982528), array(56.34168793), array(77.63027504), array(85.09303644), array(91.72086854), array(95.31574106), array(100.59113353), array(103.19167667), array(103.5258529)]
# [0.00000000e+00 2.88802557e-02 5.74745889e-02 ... 1.00609732e+02
#  1.00609293e+02 1.00608854e+02]
# [1.000000e-05 1.010000e-03 2.010000e-03 ... 2.061101e+01 2.061201e+01
#  2.061301e+01]

# %%
plt.plot(X,Y[:,1])

# %%
plt.plot(X,Y[:,0])

# %%
y0[0]=0.
y0[1]=p0_minimo
K=K_minimo

# %%
X,Y=Integrate(rhs,x0,y0,10.,h)
v=np.sqrt(Y[:,0]/X)
V,RC=model(RCr_data,v,X)
plt.errorbar(RCr_data,RCv_data,yerr=RCev_data,fmt='.')
plt.plot(RCr_data,V)
#plt.plot(X,258.444*np.sqrt(Y[:,0]/X))
#plt.xlim(0,50.50)
#plt.ylim(0.1,110)
plt.ylabel(r'$V$[km/s]')
plt.xlabel("R[kpc]")
plt.title("ESO3020120")
plt.savefig("RCESO3020120.pdf")

# %%
xi2=np.zeros((len(p_0),len(Kvec)))
for i in range(0,len(p_0)):
    for j in range (0,len(Kvec)):
        xi2_minimo=10000
        if (xi[i,j] < xi2_minimo):
            xi2_minimo=xi[i,j]
            xi2[i,j]=xi[i,j]

# %%
x,y = np.meshgrid(p_0,Kvec)
fig = plt.figure(dpi=100)
plt.contourf(x,y,xi2,400,cmap='viridis')
plt.xlabel(r'$p_0$')
plt.ylabel(r'$K$')
plt.colorbar();

# %%
diffxi2= np.zeros((len(p_0),len(Kvec)))
xicl = np.zeros((len(p_0),len(Kvec)))
for l in range(0,len(p_0)):
    for j in range(0,len(Kvec)):
        #if ((xin[l,j] ) <= 0.1388414874789144+2.30):
        diffxi2[l,j]=xi2[l,j]-xi_minimo
        if ((diffxi2[l,j] ) <= 6.18):
            xicl[l,j]=diffxi2[l,j]

# %%
x,y = np.meshgrid(p_0,Kvec)
fig = plt.figure(dpi=100)
#plt.contourf(x,y,xicl,200,cmap='viridis')
plt.contourf(x,y,xicl,200,cmap='viridis')
plt.xlabel(r'$p_0$')
plt.ylabel(r'$K$')
plt.colorbar();

# %%
k=0
long=1000000
rho_vec=np.zeros(long)
kappa_vec=np.zeros(long)
xi_vec=np.zeros(long)
xir=np.zeros((len(p_0),len(Kvec)))
k=0
ximin=1000000
for i in range(0,len(p_0)):
    for j in range(0,len(Kvec)):
        if (xi[i,j]<ximin):
            ximin=xi[i,j]       
    if ((ximin) <= 0.014733485514988055+2.30):        
    #if ((ximin) <= 0.1388414874789144+2.30):
        rho_vec[k]=p_0[i]/Kvec[i]
        kappa_vec[k]=Kvec[i]
        xi_vec[k]=ximin
        xir[i,k]=ximin
        k=k+1

# %%
r=np.zeros(long)
kapa=np.zeros(long)
dx=np.zeros(long)
c=0
for i in range(0,len(p_0)):
    for j in range(0,len(Kvec)):
        r[c]=p_0[i]/Kvec[j]
        kapa[c]=Kvec[j]
        dx[c]=xicl[i,j]
        c=c+1

# %%
print(c)
vec1=np.zeros(c)
vec2=np.zeros(c)
vec3=np.zeros(c)
for i in range(0,len(vec1)):
    if (dx[i]!=0.0):
        vec1[i]=r[i]
        vec2[i]=kapa[i]
        vec3[i]=dx[i]
# Out:
# 10000

# %%
np.savetxt("xi2ESO3020120-3.txt",np.transpose([vec1,vec2,vec3]))

# %%
print(kappa_vec)
# Out:
# [9.00000000e-09 1.11578947e-08 1.33157895e-08 ... 0.00000000e+00
#  0.00000000e+00 0.00000000e+00]

# %%
print(rho_vec)
# Out:
# [5.55555556 4.62264151 3.99209486 ... 0.         0.         0.        ]

# %%
print(xi_vec)
# Out:
# [0.57810144 0.40798888 0.27896826 ... 0.         0.         0.        ]

# %%
x,y = np.meshgrid(vec1,vec2)
fig = plt.figure(dpi=100)
#plt.contourf(x,y,xicl,200,cmap='viridis')
plt.contourf(x,y,xir,200,cmap='viridis')
plt.xlabel(r'$p_0$')
plt.ylabel(r'$K$')
plt.colorbar();
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10256/3892519439.py in <module>
#       2 fig = plt.figure(dpi=100)
#       3 #plt.contourf(x,y,xicl,200,cmap='viridis')
# ----> 4 plt.contourf(x,y,xir,200,cmap='viridis')
#       5 plt.xlabel(r'$p_0$')
#       6 plt.ylabel(r'$K$')
#
# c:\users\namh2\appdata\local\programs\python\python39\lib\site-packages\matplotlib\pyplot.py in contourf(data, *args, **kwargs)
#    2480 @_copy_docstring_and_deprecators(Axes.contourf)
#    2481 def contourf(*args, data=None, **kwargs):
# -> 2482     __ret = gca().contourf(
#    2483         *args, **({"data": data} if data is not None else {}),
#    2484         **kwargs)
#
# c:\users\namh2\appdata\local\programs\python\python39\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1410     def inner(ax, *args, data=None, **kwargs):
#    1411         if data is None:
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1413
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
# c:\users\namh2\appdata\local\programs\python\python39\lib\site-packages\matplotlib\axes\_axes.py in contourf(self, *args, **kwargs)
#    6315         """
#    6316         kwargs['filled'] = True
# -> 6317         contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6318         self._request_autoscale_view()
#    6319         return contours
#
# c:\users\namh2\appdata\local\programs\python\python39\lib\site-packages\matplotlib\contour.py in __init__(self, ax, levels, filled, linewidths, linestyles, hatches, alpha, origin, extent, cmap, colors, norm, vmin, vmax, extend, antialiased, nchunk, locator, transform, *args, **kwargs)
#     810         self._transform = transform
#     811
# --> 812         kwargs = self._process_args(*args, **kwargs)
#     813         self._process_levels()
#     814
#
# c:\users\namh2\appdata\local\programs\python\python39\lib\site-packages\matplotlib\contour.py in _process_args(self, corner_mask, *args, **kwargs)
#    1439             self._corner_mask = corner_mask
#    1440
# -> 1441             x, y, z = self._contour_args(args, kwargs)
#    1442
#    1443             _mask = ma.getmask(z)
#
# c:\users\namh2\appdata\local\programs\python\python39\lib\site-packages\matplotlib\contour.py in _contour_args(self, args, kwargs)
#    1478             args = args[1:]
#    1479         elif Nargs <= 4:
# -> 1480             x, y, z = self._check_xyz(args[:3], kwargs)
#    1481             args = args[3:]
#    1482         else:
#
# c:\users\namh2\appdata\local\programs\python\python39\lib\site-packages\matplotlib\contour.py in _check_xyz(self, args, kwargs)
#    1527         elif x.ndim == 2:
#    1528             if x.shape != z.shape:
# -> 1529                 raise TypeError(
#    1530                     f"Shapes of x {x.shape} and z {z.shape} do not match")
#    1531             if y.shape != z.shape:
#
# TypeError: Shapes of x (400, 400) and z (20, 20) do not match
